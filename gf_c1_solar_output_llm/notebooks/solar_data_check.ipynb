# %% [markdown]
# ### Solar Data Check

# %%
import rasterio

TIF_DIR = "Australia_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF"
TIF_PATH = f"../data/{TIF_DIR}/PVOUT.tif"  

with rasterio.open(TIF_PATH) as src:
  print(src.tags())  # Check for timestamp or date metadata
  print(src.meta)
  print(src.descriptions)
# Out:
# {'AREA_OR_POINT': 'Area', 'TIFFTAG_ARTIST': 'Solargis', 'TIFFTAG_COPYRIGHT': '(c) 2019 Solargis', 'TIFFTAG_IMAGEDESCRIPTION': 'This datalayer has been prepared by Solargis for the Global Solar Atlas (https://globalsolaratlas.info/), online platform funded by the Energy Sector Management Assistance Program(ESMAP), a multi-donor trust fund administered by The World Bank, under a global initiative on Renewable Energy Resource Mapping. The data is published in Global Solar Atlas under a Creative Commons 4.0 Attribution International license. For more information, see the enclosed XML or PDF metadata file.'}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': nan, 'width': 5760, 'height': 4200, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.008333333333333333, 0.0, 112.0,
#        0.0, -0.008333333333333333, -9.0)}
# (None,)
